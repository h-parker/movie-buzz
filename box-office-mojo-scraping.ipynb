# %%
from bs4 import BeautifulSoup
import requests

# %%
# Make a get request to retrieve the page
html_page = requests.get('https://www.boxofficemojo.com/movies/?id=untitledtarantino.htm') 

# Pass the page contents to beautiful soup for pars
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN" "http://www.w3.org/TR/html4/loose.dtd">
#
# <html lang="en">
# <head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <title>Once Upon a Time in Hollywood (2019) - Box Office Mojo</title>
# <style type="text/css">
# table.chart-wide { width: 100%; }
# </style>
# <meta content="once upon a time in hollywood, movie, film, box office, result, records, charts, revenue, opening weekend, gross, worldwide, overseas, foreign, news, reviews, articles, stories, story, analysis, revenue, release date, mpaa rating, genre, running time, length, budget, production budget, distributor, studio, sony / columbia, theatrical summary, theatrical, daily box office results, weekend box office results, weekly box office, box office mojo" name="keywords"/>
# <meta content="Once Upon a Time in Hollywood summary of box office results, charts and release information and related links." name="description"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="screen" rel="stylesheet" title="no title" type="text/css"/>
# <link charset="utf-8" href="/css/mojo.css?1" media="print" rel="stylesheet" title="no title" type="text/css"/>
# <script src="/js/jscharts.js" type="text/javascript"></script>
# </head>
# <body>
# <iframe frameborder="0" height="1" id="sis_pixel_sitewide" marginheight="0" marginwidth="0" style="display: none;" width="1"></iframe>
# <script>
#     setTimeout(function(){
#         try{
#             //sis3.0 pixel
#             var cacheBust = Math.random() * 10000000000000000,
#                 url_sis3 = '//s.amazon-adsystem.com/iu3?',
#                 params_sis3 = [
#                     "d=boxofficemojo.com",
#                     "cb=" + cacheBust
#                 ];
#
#             (document.getElementById('sis_pixel_sitewide')).src = url_sis3 + params_sis3.join('&');
#         }catch(e){
#             if (window.ueLogError) {
#                 window.ueLogError(e);
#             }
#         }
#     }, 5);
# </script>
# <div id="container">
# <div>
# <script type="text/javascript">
#     var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#
#     (function() {
#         var gads = document.createElement("script");
#         gads.async = true;
#         gads.type = "text/javascript";
#
#         var useSSL = "https:" == document.location.protocol;
#         gads.src = (useSSL ? "https:" : "http:") + "//www.googletagservices.com/tag/js/gpt.js";
#
#         var node = document.getElementsByTagName("script")[0];
#         node.parentNode.insertBefore(gads, node);
#     })();
# </script>
# <script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2831726-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     (document.getElementsByTagName('head')[0] || document.getElementsByTagName('body')[0]).appendChild(ga);
#   })();
#
# </script>
# <div id="hp_banner">
# <div id="top_links">
# <div style="float: left"><a href="/daily/chart/">Daily Box Office (Sun.)</a> | <a href="/weekend/chart/">Weekend Box Office (Jul. 26–28)</a> | <a href="/movies/?id=lionkingliveaction.htm">#1 Movie: 'The Lion King'</a> | <a href="http://www.imdb.com/showtimes/?ref_=mojo">Showtimes</a></div>
# <div style="float: right">Updated 7/28/2019 8:25 A.M. Pacific Time</div>
# <div style="clear:both; height: 0px"></div>
# </div>
# </div>
# <div id="header">
# <div id="leaderboard"><script src="//bs.serving-sys.com/Serving/adServer.bs?c=28&amp;cn=display&amp;pli=1073982656&amp;w=728&amp;h=90&amp;ord=1564426442&amp;z=0"></script>
# <noscript>
# <a href="//bs.serving-sys.com/Serving/adServer.bs?cn=brd&amp;pli=1073982656&amp;Page=&amp;Pos=668343950" target="_blank">
# <img border="0" height="90" src="//bs.serving-sys.com/Serving/adServer.bs?c=8&amp;cn=display&amp;pli=1073982656&amp;Page=&amp;Pos=668343950" width="728"/>
# </a>
# </noscript>
# </div>
# <div id="leaderboard"><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[728, 90]], "ad-slot-1").addService(googletag.pubads().setTargeting("p", "t"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-1"); });
# </script></div> <div id="hp_logo"><a href="/"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a></div>
# <div style="clear:both; height: 0px"></div>
# </div>
# </div>
# <div class="connect_nav">
# <ul>
# <li class="nl_link">
# <a href="http://pro.imdb.com/signup/index.html?rf=mojo_nb_hm&amp;ref_=mojo_nb_hm" target="_blank">
# <img alt="Get industry info at IMDbPro" height="20" src="/images/IMDbPro.png">
# </img></a>
# </li>
# <li class="nl_link">
# <a href="http://twitter.com/boxofficemojo" target="_blank">
# <img alt="Follow us on Twitter" height="18" src="/images/glyphicons-social-32-twitter@2x.png">
# </img></a>
# </li>
# <li class="nl_link">
# <a href="http://facebook.com/boxofficemojo" target="_blank">
# <img alt="Follow us on Facebook" height="18" src="/images/glyphicons-social-31-facebook@2x.png"/>
# </a>
# </li>
# </ul>
# </div>
# <div id="main">
# <!-- COLUMN 1 of 4 -->
# <div id="leftnav">
# <!-- google_ad_section_start(weight=ignore) -->
# <!-- <table id="navleft" cellspacing="0" cellpadding="2" border="0"> -->
# <ul id="leftnav">
# <li class="nl_section">Search Site</li>
# <li class="nl_link" style="padding-left:0px">
# <form action="/search/q.php" method="POST" name="searchbox">
# <input name="q" style="font-size: 9 pt; font-weight: bold; width: 90px;" type="text"/><br/>
# <input type="submit" value="Search..."/></form>
# </li>
# <li class="nl_section">Features</li>
# <li class="nl_link"><a href="/news/">News</a></li>
# <li class="nl_link"><a href="/schedule/">Release Sched.</a></li>
# <li class="nl_link"><a href="http://www.imdb.com/showtimes?ref_=mojo">Showtimes<br><span style="margin-left:7px;color: #999999; font-size: 9px;">at <img src="/images/mojo_imdb_sm.png"/></span></br></a></li>
# <li class="nl_section">Box Office</li>
# <li class="nl_link"><a href="/daily/">Daily</a></li>
# <li class="nl_link"><a href="/weekend/">Weekend</a></li>
# <li class="nl_link"><a href="/weekly/">Weekly</a></li>
# <li class="nl_link"><a href="/monthly/">Monthly</a></li>
# <li class="nl_link"><a href="/quarterly/">Quarterly</a></li>
# <li class="nl_link"><a href="/seasonal/">Seasonal</a></li>
# <li class="nl_link"><a href="/yearly/">Yearly</a></li>
# <li class="nl_link"><a href="/alltime/">All Time</a></li>
# <li class="nl_link"><a href="/intl/">International</a></li>
# <li class="nl_section">Indices</li>
# <li class="nl_link"><a href="/studio/">Studios</a></li>
# <li class="nl_link"><a href="/people/">People</a></li>
# <li class="nl_link"><a href="/genres/">Genres</a></li>
# <li class="nl_link"><a href="/franchises/">Franchises</a></li>
# <li class="nl_link"><a href="/showdowns/">Showdowns</a></li>
# <li class="nl_link"><a href="/counts/">Theater Counts</a></li>
# </ul>
# </div>
# <div id="body">
# <table border="0" cellspacing="0" width="878px">
# <tr>
# <td align="right" style="whitespace:nowrap;">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <form action="/adjuster.php" method="POST" name="adjuster">
# <input name="returnURL" type="hidden" value="/movies/?id=untitledtarantino.htm"/>
# <td valign="center">
# <font face="Verdana" size="2"><a href="/about/adjuster.htm"><b>Adjuster:</b></a></font>
# <select name="ticketyr" size="1" style="font-family: Verdana; font-size: 10pt">
# <option selected="" value="0">Actuals</option>
# <option value="1">Est. Tckts</option>
# <script language="javascript">
#   for(i=2019; i>=1933; i--) {
#   	document.write('<option value="' + i + '"');
# 	if(i=='0') document.write(' selected');
# 	document.write('>' + i );
# 	if(i=='0') document.write(', $' + '0.00');
# 	document.write('</option>');
#   }
# </script>
# <option value="1929">1929</option>
# <option value="1924">1924</option>
# <option value="1910">1910</option>
# </select><input name="Go" style="font-size: 10pt; height: 22" type="submit" value="Go"/>
# </td></form></tr></table>
# </td></tr>
# <!--------------------------Site Body---------------------------------->
# <tr></tr></table></div></div></div></body></html>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr> <td valign="top">
# <table border="0" cellpadding="0" cellspacing="0" style="padding-top: 5px;" width="100%"><tr><td align="center" valign="top">
# <a href="/movies/?page=media&amp;id=untitledtarantino.htm"><img border="1" src="https://m.media-amazon.com/images/M/MV5BOTg4ZTNkZmUtMzNlZi00YmFjLTk1MmUtNWQwNTM0YjcyNTNkXkEyXkFqcGdeQXVyNjg2NjQwMDQ@._V1_UY222_CR0,0,150,222_AL.jpg" style="border-color: 000000"/></a> </td>
# <td align="center" valign="top"><br/><font face="Verdana" size="5"><b>Once Upon a Time in Hollywood</b></font><br/><br/>
# <table border="0" cellpadding="0" cellspacing="0"><tr><td>
# <center><table bgcolor="#dcdcdc" border="0" cellpadding="4" cellspacing="1" width="95%"><tr bgcolor="#ffffff"><td align="center" colspan="2"><font size="4"><font size="3">Domestic Total as of Jul. 28, 2019:</font> <b>$40,350,000 (Estimate)</b></font></td></tr><tr bgcolor="#ffffff"><td valign="top">Distributor: <b><a href="/studio/chart/?studio=sony.htm">Sony / Columbia</a></b></td><td valign="top">Release Date: <b><nobr><a href="/schedule/?view=bydate&amp;release=theatrical&amp;date=2019-07-26&amp;p=.htm">July 26, 2019</a></nobr></b></td></tr><tr bgcolor="#ffffff"><td valign="top">Genre: <b>Comedy / Drama</b></td><td valign="top">Runtime: <b>2 hrs. 41 min.</b></td></tr><tr bgcolor="#ffffff"><td valign="top">MPAA Rating: <b>R</b></td><td valign="top">Production Budget: <b>$90 million</b></td></tr></table> </center></td>
# </tr></table></td>
# <td align="right"><script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[300, 250]], "ad-slot-2").addService(googletag.pubads().setTargeting("p", "rh"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-2"); });
# </script></td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0" width="878px">
# <tr><td>
# <ul class="nav_tabs">
# <li class="nav_tab_current"><a href="/movies/?page=main&amp;id=untitledtarantino.htm">Summary</a></li>
# <li><a href="/movies/?page=daily&amp;id=untitledtarantino.htm">Daily</a></li>
# <li><a href="/movies/?page=weekend&amp;id=untitledtarantino.htm">Weekend</a></li>
# </ul>
# <br>
# </br></td></tr>
# <tr><td>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tr><td valign="top" width="434px">
# <table border="0" cellpadding="0" cellspacing="0" width="100%"><tr>
# <td valign="top" width="50%">
# <div class="mp_box">
# <div class="mp_box_tab">Total Lifetime Grosses</div></div></td></tr></table></td></tr></table></td></tr></table></td></tr></table>
# <div class="mp_box_content">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td width="40%"><b>Domestic:</b></td>
# <td align="right" width="35%"> <b>$40,350,000</b></td>
# </tr>
# </table>
# </div>
#
# <div class="mp_box">
# <div class="mp_box_tab">Domestic Summary</div></div>
# <div class="mp_box_content">
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td align="center"><a href="/weekend/chart/?yr=2019&amp;wknd=30&amp;p=.htm">Opening Weekend:</a></td><td> $40,350,000</td></tr>
# <tr>
# <td align="center" colspan="2"><font size="2">(#2 rank, 3,659 theaters, $11,028 average)</font></td></tr>
# <tr>
# <td align="right">% of Total Gross:</td><td> 100.0%</td></tr>
# <tr><td align="right" colspan="2"><font face="Helvetica, Arial, Sans-Serif" size="1"><a href="/movies/?page=weekend&amp;id=untitledtarantino.htm"><b>&gt; View All Weekends</b></a></font></td></tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td>Widest Release:</td>
# <td> 3,659 theaters</td>
# </tr>
# </table>
# <table border="0" cellpadding="0" cellspacing="0">
# <tr>
# <td>In Release:</td>
# <td> 3 days / 0.4 weeks</td>
# </tr>
# </table>
# </div>
#
#
# <td style="padding-left: 10px;" valign="top"><div class="mp_box">
# <div class="mp_box_tab">The Players</div>
# <div class="mp_box_content">
# <table>
# </table></div></div></td><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Director&amp;p=.htm">Director:</a></font></td></tr><td><font size="2"><a href="/people/chart/?view=Director&amp;id=tarantino.htm">Quentin Tarantino</a></font></td><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Writer&amp;p=.htm">Writer:</a></font></td></tr><td><font size="2"><a href="/people/chart/?view=Writer&amp;id=tarantino.htm">Quentin Tarantino</a></font></td><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Actor&amp;p=.htm">Actors:</a></font></td></tr><td><font size="2"><a href="/people/chart/?view=Actor&amp;id=leonardodicaprio.htm">Leonardo DiCaprio</a><br/><a href="/people/chart/?view=Actor&amp;id=bradpitt.htm">Brad Pitt</a><br/><a href="/people/chart/?view=Actor&amp;id=margotrobbie.htm">Margot Robbie</a><br/><a href="/people/chart/?view=Actor&amp;id=dakotafanning.htm">Dakota Fanning</a><br/><a href="/people/chart/?view=Actor&amp;id=alpacino.htm">Al Pacino</a><br/>Harley Quinn Smith<br/><a href="/people/chart/?view=Actor&amp;id=kurtrussell.htm">Kurt Russell</a><br/>Luke Perry<br/>Emile Hirsch<br/>Michael Madsen<br/>Rumer Willis</font></td><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Producer&amp;p=.htm">Producers:</a></font></td></tr><td><font size="2"><a href="/people/chart/?view=Producer&amp;id=davidheyman.htm">David Heyman</a><br/>Shannon McIntosh<br/><a href="/people/chart/?view=Producer&amp;id=tarantino.htm">Quentin Tarantino</a></font></td><tr><td align="right" valign="top"><font size="2"><a href="/people/?view=Cinematographer&amp;p=.htm"><font size="2">Cinematographer</font>:</a></font></td></tr><td><font size="2">Robert Richardson</font></td>
#
# <div class="mp_box">
# <div class="mp_box_tab">Genres</div>
# <div class="mp_box_content">
# <table border="0" cellpadding="5" cellspacing="1" style="border-collapse: collapse" width="100%">
# <tr><th>Genre</th>
# <th>Rank</th></tr>
# <tr bgcolor="#ffffff"><td><font size="2"><a href="/genres/chart/?id=hollywoodmovies.htm">Hollywood / Movies</a></font></td>
# <td align="center"><font size="2">22</font></td>
# </tr>
# </table>
# </div></div>
# <div class="mp_box">
# <div class="mp_box_tab">Franchises</div>
# <div class="mp_box_content">
# <table border="0" cellpadding="5" cellspacing="1" style="border-collapse: collapse" width="100%">
# <tr><th>Franchise</th>
# <th>Rank</th></tr>
# <tr bgcolor="#f4f4ff"><td><font size="2"><a href="/showdowns/chart/?id=tarantinovs.htm"><b>Showdown: Tarantino Showdown</b></a></font></td>
# <td align="center"><font size="2"><b>3</b></font></td>
# </tr>
# </table></div></div><div class="mp_box">
# <div class="mp_box_tab">Charts</div>
# <div class="mp_box_content">
# <table border="0" cellpadding="5" cellspacing="1" style="border-collapse: collapse" width="100%">
# <tr
http://ws.amazon.com/widgets/q?ServiceVersion=20070822&amp;MarketPlace=US&amp;ID=V20070822%2FUS%2Fboxofficemojo-20%2F8010%2F82160f42-9620-4d0a-b79a-18b1abd853fb&amp;Operation=NoScript">Amazon.com Widgets</a></noscript>
# </td>
#
#
# <br/>
#
#
#
#
#
#
# <div id="hp_footer">
# <div style="padding-bottom: 20px;">
# <div style="margin: 0px 121px; vertical-align: top;">
# <div id="footer_links">
# <ul class="footer_link_list">
# <li><strong>Latest Updates</strong></li>
# <li><a href="/news/?ref=ft">Movie News</a>
# <li><a href="/daily/chart/?ref=ft">Daily Chart</a></li>
# <li><a href="/weekend/chart/?ref=ft">Weekend Chart</a></li>
# <li><a href="/alltime/?ref=ft">All Time Charts</a></li>
# <li><a href="/intl/?ref=ft">International Charts</a></li>
# </li></ul>
# <!--
# 					<ul class="footer_link_list">
# 						<li><strong>Popular Movies</strong></li>
# 											</ul>
# 					-->
# <ul class="footer_link_list">
# <li><strong>Indices</strong></li>
# <li><a href="/people/?ref=ft">People</a></li>
# <li><a href="/genres/?ref=ft">Genres</a></li>
# <li><a href="/franchises/?ref=ft">Franchises</a></li>
# <li><a href="/showdowns/?ref=ft">Showdowns</a></li>
# </ul>
# <ul class="footer_link_list">
# <li><strong>Other</strong></li>
# <li><a href="/about/?ref=ft">About This Site</a></li>
# <li><a href="/about/advertise.htm?ref=ft">Advertising</a></li>
# </ul>
# </div>
# <div id="copyright">
# <a href="/?ref=ft"><img alt="Box Office Mojo" height="56" src="/img/misc/bom_logo1.png" width="245"/></a><br/>
# <p>An <a href="http://imdb.com/"><img alt="IMDb" height="16" src="/img/misc/IMDbSm.png" valign="middle" width="34"/></a> company<br/><br/></p>
# <p>© <a href="http://imdb.com/">IMDb.com</a>, Inc. or its affiliates. All rights reserved. Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates. <a href="/about/termsofuse.htm">Terms of Use</a> and <a href="/about/privacy.htm">Privacy Policy</a> under which this service is provided to you.</p>
# </div>
# </div>
# <div style="clear:both;">
# <div>
# <script type="text/javascript">
#     googletag.cmd.push(function() {
#         googletag.defineSlot("/4215/imdb2.bom.movie", [[728, 90]], "ad-slot-3").addService(googletag.pubads().setTargeting("p", "b"));
#         googletag.pubads().enableSingleRequest();
#         googletag.enableServices();
#     });
#     googletag.cmd.push(function() { googletag.display("ad-slot-3"); });
# </script></div>
# </div>
# </div>
# </div>
# <!-- Page generated in 0.06 seconds | . -->
# <script>
#   var _comscore = _comscore || [];
#   _comscore.push({ c1: "2", c2: "6034961" });
#   (function() {
#     var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true;
#     s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js";
#   el.parentNode.insertBefore(s, el);
#   })();
# </script>
# <noscript>
# <img src="http://b.scorecardresearch.com/p?c1=2&amp;c2=6034961&amp;cv=2.0&amp;cj=1">
# </img></noscript>

# %%
info = {}

# function to get replace multiple different substrings with one 
# particular substring in a given string
def replace_multiple(string, to_replace_list, replacement):
    for to_replace in to_replace_list:
        string = string.replace(to_replace, replacement)
    return string



findings = list(soup.find_all('b'))

info['title'] = replace_multiple(str(findings[1]), ['<b>', '</b>', '<br/>'], '')
# typically, there are multiple genres, separated by a '/', so we 
# get this string into a list of genres by splitting after replacing random characters
info['genre'] = [x for x in replace_multiple(str(findings[5]), ['<b>', '</b>'], '').split('/')]
info['rating'] = replace_multiple(str(findings[7]), ['<b>', '</b>'], '')
info['budget'] = replace_multiple(str(findings[8]), ['<b>', '</b>'], '')

info
# Out:
# {'title': 'Once Upon a Time in Hollywood',
#  'genre': ['Comedy ', ' Drama'],
#  'rating': 'R',
#  'budget': '$90 million'}

# %%
# Make a get request to retrieve the page
html_page = requests.get('https://www.boxofficemojo.com/movies/?page=main&id=spidermanhomecoming2.htm') 

# Pass the page contents to beautiful soup for pars
soup1 = BeautifulSoup(html_page.content, 'html.parser')

# %%
soup1.find_all('b')
# Out:
# [<b>Adjuster:</b>,
#  <b>Spider-Man:<br/>Far from Home</b>,
#  <b>$344,455,270 (Estimate)</b>,
#  <b><a href="/studio/chart/?studio=sony.htm">Sony / Columbia</a></b>,
#  <b><nobr><a href="/schedule/?view=bydate&amp;release=theatrical&amp;date=2019-07-02&amp;p=.htm">July 2, 2019</a></nobr></b>,
#  <b>Action / Adventure</b>,
#  <b>2 hrs. 9 min.</b>,
#  <b>PG-13</b>,
#  <b>$160 million</b>,
#  <b>Domestic:</b>,
#  <b>$344,455,270</b>,
#  <b>33.2%</b>,
#  <b>Worldwide:</b>,
#  <b>$1,036,855,270</b>,
#  <b>&gt; View All 4 Weekends</b>,
#  <b>Series: Marvel Cinematic Universe</b>,
#  <b>10</b>,
#  <b>Series: Spider-Man</b>,
#  <b>3</b>,
#  <b>Chart</b>,
#  <b>Rank</b>,
#  <b>Top Movies in the Past 365 Days</b>,
#  <b>6</b>,
#  <b>Non-Friday Opening Weekends</b>,
#  <b>6</b>,
#  <b>Opening Tuesdays</b>,
#  <b>1</b>,
#  <b>Non-Opening Friday Gross</b>,
#  <b>7</b>,
#  <b>Non-Opening Thursday Gross</b>,
#  <b>3</b>,
#  <b>Non-Opening Wednesday Gross</b>,
#  <b>4</b>,
#  <b>Single Day Thursday Gross</b>,
#  <b>7</b>,
#  <b>Single Day Tuesday Gross</b>,
#  <b>1</b>,
#  <b>Opening Weekends - July</b>,
#  <b>10</b>,
#  <b>Independence Day Opening Weekends</b>,
#  <b>2</b>,
#  <b>Independence Day Weekends</b>,
#  <b>2</b>,
#  <b>Widest Releases</b>,
#  <b>3</b>,
#  <b>Widest Opening Releases</b>,
#  <b>3</b>,
#  <b>Widest PG-13 Rated Openings</b>,
#  <b>2</b>,
#  <b>Widest PG-13 Rated Releases</b>,
#  <b>2</b>,
#  <b>Charts (Premier Pass Users Only)</b>,
#  <b>Rank</b>,
#  <b>Non-Opening Thursday Gross Adjusted</b>,
#  <b>9</b>,
#  <b>Non-Opening Wednesday Gross Adjusted</b>,
#  <b>4</b>,
#  <b>Single Day Tuesday Gross Adjusted</b>,
#  <b>2</b>]

# %%
findings = list(soup1.find_all('b'))

info['title'] = replace_multiple(str(findings[1]), ['<b>', '</b>', '<br/>'], '')
info['genre'] = [x for x in replace_multiple(str(findings[5]), ['<b>', '</b>'], '').split('/')]
info['rating'] = replace_multiple(str(findings[7]), ['<b>', '</b>'], '')
info['budget'] = replace_multiple(str(findings[8]), ['<b>', '</b>'], '')

info
# Out:
# {'title': 'Spider-Man:Far from Home',
#  'genre': ['Action ', ' Adventure'],
#  'rating': 'PG-13',
#  'budget': '$160 million'}

# %%
html_page = requests.get('https://www.boxofficemojo.com/yearly/chart/?page=1&view=releasedate&view2=domestic&yr=2017&p=.htm') 

# Pass the page contents to beautiful soup for pars
soup2 = BeautifulSoup(html_page.content, 'html.parser')
links = []
for x in list(soup2.find_all('tr')):
    for y in x.findChildren('td'):
        for z in y.findChildren('a'):
            if 'movies' in str(z.get('href')):
                links.append(z.get('href'))
            
len(set(links))
set(links)
# Out:
# {'/movies/?id=47metersdown.htm',
#  '/movies/?id=adogspurpose.htm',
#  '/movies/?id=alienparadiselost.htm',
#  '/movies/?id=allthemoneyintheworld.htm',
#  '/movies/?id=amadeahalloween2.htm',
#  '/movies/?id=americanassassin.htm',
#  '/movies/?id=annabelle2.htm',
#  '/movies/?id=babydriver.htm',
#  '/movies/?id=badmomschristmas.htm',
#  '/movies/?id=baywatch.htm',
#  '/movies/?id=beautyandthebeast2017.htm',
#  '/movies/?id=bladerunnersequel.htm',
#  '/movies/?id=blumhouse2.htm',
#  '/movies/?id=blumhousehorror2018.htm',
#  '/movies/?id=bossbaby.htm',
#  '/movies/?id=captainunderpants.htm',
#  '/movies/?id=cars3.htm',
#  '/movies/?id=chrisnolan2017.htm',
#  '/movies/?id=daddyshome2.htm',
#  '/movies/?id=darkesthour2017.htm',
#  '/movies/?id=darktower.htm',
#  '/movies/?id=dcfilm1117.htm',
#  '/movies/?id=despicableme3.htm',
#  '/movies/?id=downsizing.htm',
#  '/movies/?id=everythingeverything.htm',
